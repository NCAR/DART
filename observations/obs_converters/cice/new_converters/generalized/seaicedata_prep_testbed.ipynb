# %% [markdown]
# The goal of this notebook is to develop a data preprocessing script that will:
# - Read in a sea ice data file
# - determine the type of data
# - standardize the naming conventions of (x,y) dimensions as (ni,nj), the data and errors as (data), (error), and the latitude and longitude as (lat, lon)
# - write a netcdf file containing the necessary data and metadata to a desired location

# %%
import xarray as xr
# import pandas as pd
import os
import glob
import h5py
import numpy as np

# %%
icesat2_names = ['ICESAT2', 'ICESAT-2', 'IS2', 'IS-2', 'Icesat2','Icesat-2','IceSat-2', 'icesat2','icesat-2','is2','is-2']

# %%
name = 'is2'

# %%
def determine_data_source(name, data_type):
    if name in icesat2_names:
        if data_type in ['freeboard', 'fb', 'hi']:
            print("You're converting freeboard data from NASA's ICESat-2 mission.")
        read_is2_data(data_type)
    else:
        raise NotImplementedError

# %%
def read_is2_data(data_type, start_date = '2019.01.01', tracks = ['gt1r', 'gt1l', 'gt2r', 'gt2l', 'gt3r', 'gt3l'], 
                  input_path = '/glade/scratch/mollyw/external_data/ICESat-2/thickness/',
                  output_path = '/glade/scratch/mollyw/external_data/IS2_reduced/thickness/'):
    
    days_of_year = [31,29,31,30,31,30,31,31,30,31,30,31]
    year = start_date[0:4]
    dir_list = [name for name in sorted(os.listdir(input_path))]
    print(dir_list)
    
    if os.path.isdir(output_path) is False:
        print('Output directory presently does not exist! Generating directory now.')
        os.makedirs(output_path)
    else:
        print('Output directory exists! Nice!')
    
    # THICKNESS PREP
    if data_type in ['thickness', 'hi', 'sithick','SIT']:
        for dir_day in dir_list:
            files = sorted(glob.glob(input_path+dir_day+'/IS2SITDAT4_01*.nc'))
            if len(files) == 0:
                FileNotFoundError('I did not find any IS2 thickness data in your system for this date. Please check if data is available in correct directories.')
            else:
                generate_thickness_netcdf(files, dir_day, output_path)
                
        check = os.listdir(output_path)
        if len(check) == 0:
            FileNotFoundError('No files were converted! Please debug.')
    
    # FREEBOARD PREP
    elif data_type in ['freeboard', 'fb', 'FB']:
        for dir_day in dir_list:
            files = sorted(glob.glob(input_path+dir_day+'/ATL10-01*[0-9]*.h5'))
            if len(files) == 0:
                FileNotFoundError('I did not find any IS2 freeboard data in your system for this date. Please check if data is available in correct directories.')
            else:
                generate_freeboard_netcdf(files, tracks, dir_day, output_path)
                
        check = os.listdir(output_path)
        if len(check) == 0:
            FileNotFoundError('No files were converted! Please debug.')
    
    # YET NOT IMPLEMENTED PREP      
    elif data_type in ['concentration', 'siconc','aice','SIC']:
        raise NotImplementedError('Not finished')
        
    elif data_type in ['motion']:
        raise NotImplementedError('Not currently supported')
        
    elif data_type in ['snow']:
        raise NotImplementedError('Not currently supported')
        
    elif data_type in ['ice_age', 'age']:
        raise NotImplementedError('Not currently supported')
        
    else:
        raise NotImplementedError("The type of data you wish to convert is not supported. Please contact DAReS if you wish to add support for your data type.")

# %%
determine_data_source(name, 'hi')
# Out:
# You're converting freeboard data from NASA's ICESat-2 mission.
# ['2019.01.01', '2019.01.02', '2019.01.03', '2019.01.04', '2019.01.05', '2019.01.06', '2019.01.07', '2019.01.08', '2019.01.09', '2019.01.10', '2019.01.11', '2019.01.12', '2019.01.13', '2019.01.14', '2019.01.15', '2019.01.16', '2019.01.17', '2019.01.18', '2019.01.19', '2019.01.20', '2019.01.21', '2019.01.22', '2019.01.23', '2019.01.24', '2019.01.25', '2019.01.26', '2019.01.27', '2019.01.28', '2019.01.29', '2019.01.30', '2019.01.31']
# Output directory exists! Nice!
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/coding/times.py:240, in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     239 try:
# --> 240     dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     241 except (KeyError, OutOfBoundsDatetime, OverflowError):
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/coding/times.py:215, in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     211 # Use pd.to_timedelta to safely cast integer values to timedeltas,
#     212 # and add those to a Timestamp to safely produce a DatetimeIndex.  This
#     213 # ensures that we do not encounter integer overflow at any point in the
#     214 # process without raising OutOfBoundsDatetime.
# --> 215 return (pd.to_timedelta(flat_num_dates_ns_int, "ns") + ref_date).values
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/arraylike.py:100, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
# --> 100     return self._arith_method(other, operator.add)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/indexes/base.py:6717, in Index._arith_method(self, other, op)
#    6715     return NotImplemented
# -> 6717 return super()._arith_method(other, op)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/base.py:1295, in IndexOpsMixin._arith_method(self, other, op)
#    1294 with np.errstate(all="ignore"):
# -> 1295     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1297 return self._construct_result(result, name=res_name)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:216, in arithmetic_op(left, right, op)
#     209 if (
#     210     should_extension_dispatch(left, right)
#     211     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)
#     214     # Timedelta/Timestamp and other custom scalars are included in the check
#     215     # because numexpr will fail on it, see GH#31457
# --> 216     res_values = op(left, right)
#     217 else:
#     218     # TODO we should handle EAs consistently and move this check before the if/else
#     219     # (https://github.com/pandas-dev/pandas/issues/41165)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:1264, in DatetimeLikeArrayMixin.__add__(self, other)
#    1263 elif isinstance(other, (datetime, np.datetime64)):
# -> 1264     result = self._add_datetimelike_scalar(other)
#    1265 elif isinstance(other, Period) and is_timedelta64_dtype(self.dtype):
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/arrays/timedeltas.py:482, in TimedeltaArray._add_datetimelike_scalar(self, other)
#     481 i8 = self.asi8
# --> 482 result = checked_add_with_arr(i8, other.value, arr_mask=self._isnan)
#     483 result = self._maybe_mask_results(result)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/pandas/core/algorithms.py:1114, in checked_add_with_arr(arr, b, arr_mask, b_mask)
#    1113 if to_raise:
# -> 1114     raise OverflowError("Overflow in int64 addition")
#    1115 return arr + b
#
# OverflowError: Overflow in int64 addition
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 determine_data_source(name, 'hi')
#
# Input In [42], in determine_data_source(name, data_type)
#       3     if data_type in ['freeboard', 'fb', 'hi']:
#       4         print("You're converting freeboard data from NASA's ICESat-2 mission.")
# ----> 5     read_is2_data(data_type)
#       6 else:
#       7     raise NotImplementedError
#
# Input In [61], in read_is2_data(data_type, start_date, tracks, input_path, output_path)
#      21         FileNotFoundError('I did not find any IS2 thickness data in your system for this date. Please check if data is available in correct directories.')
#      22     else:
# ---> 23         generate_thickness_netcdf(files, dir_day, output_path)
#      25 check = os.listdir(output_path)
#      26 if len(check) == 0:
#
# Input In [60], in generate_thickness_netcdf(files, dir_day, output_path)
#      25     time = list(ds.gps_seconds.values)
#      27     # make dataset, decode time to cftime object, and save in a list
# ---> 28     data_list.append(xr.decode_cf(xr.Dataset({"data": (["time"], data),
#      29                                               "error": (["time"], unc),
#      30                                               "lon": (["time"], longitude),
#      31                                               "lat": (["time"], latitude)
#      32                                              }, coords={"time": (['time'],
#      33                                                                  time,
#      34                                                                  {"units": "seconds since 1980-01-06"}
#      35                                                                 )
#      36                                                        }
#      37                                             )
#      38                                  )
#      39                     )
#      41 day_data = xr.concat(data_list, dim = 'time', compat = 'no_conflicts')
#      42 filename = 'IS2_hi_'+dir_day+'.nc'
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/conventions.py:657, in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     644     raise TypeError("can only decode Dataset or DataStore objects")
#     646 vars, attrs, coord_names = decode_cf_variables(
#     647     vars,
#     648     attrs,
#    (...)
#     655     decode_timedelta=decode_timedelta,
#     656 )
# --> 657 ds = Dataset(vars, attrs=attrs)
#     658 ds = ds.set_coords(coord_names.union(extra_coords).intersection(vars))
#     659 ds.set_close(close)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/dataset.py:751, in Dataset.__init__(self, data_vars, coords, attrs)
#     748 if isinstance(coords, Dataset):
#     749     coords = coords.variables
# --> 751 variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#     752     data_vars, coords, compat="broadcast_equals"
#     753 )
#     755 self._attrs = dict(attrs) if attrs is not None else None
#     756 self._close = None
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/merge.py:488, in merge_data_and_coords(data, coords, compat, join)
#     486 explicit_coords = coords.keys()
#     487 indexes = dict(_extract_indexes_from_coords(coords))
# --> 488 return merge_core(
#     489     objects, compat, join, explicit_coords=explicit_coords, indexes=indexes
#     490 )
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/merge.py:637, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     633 coerced = coerce_pandas_values(objects)
#     634 aligned = deep_align(
#     635     coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     636 )
# --> 637 collected = collect_variables_and_indexes(aligned)
#     639 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#     640 variables, out_indexes = merge_collected(
#     641     collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     642 )
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/merge.py:296, in collect_variables_and_indexes(list_of_mappings)
#     293     indexes.pop(name, None)
#     294     append_all(coords, indexes)
# --> 296 variable = as_variable(variable, name=name)
#     298 if variable.dims == (name,):
#     299     idx_variable = variable.to_index_variable()
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/variable.py:163, in as_variable(obj, name)
#     157     if obj.ndim != 1:
#     158         raise MissingDimensionsError(
#     159             f"{name!r} has more than 1-dimension and the same name as one of its "
#     160             f"dimensions {obj.dims!r}. xarray disallows such variables because they "
#     161             "conflict with the coordinates used to label dimensions."
#     162         )
# --> 163     obj = obj.to_index_variable()
#     165 return obj
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/variable.py:535, in Variable.to_index_variable(self)
#     533 def to_index_variable(self):
#     534     """Return this variable as an xarray.IndexVariable"""
# --> 535     return IndexVariable(
#     536         self.dims, self._data, self._attrs, encoding=self._encoding, fastpath=True
#     537     )
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/variable.py:2614, in IndexVariable.__init__(self, dims, data, attrs, encoding, fastpath)
#    2612 # Unlike in Variable, always eagerly load values into memory
#    2613 if not isinstance(self._data, PandasIndexingAdapter):
# -> 2614     self._data = PandasIndexingAdapter(self._data)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/indexing.py:1271, in PandasIndexingAdapter.__init__(self, array, dtype)
#    1270 def __init__(self, array: pd.Index, dtype: DTypeLike = None):
# -> 1271     self.array = utils.safe_cast_to_index(array)
#    1273     if dtype is None:
#    1274         if isinstance(array, pd.PeriodIndex):
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/utils.py:117, in safe_cast_to_index(array)
#     115     if hasattr(array, "dtype") and array.dtype.kind == "O":
#     116         kwargs["dtype"] = object
# --> 117     index = pd.Index(np.asarray(array), **kwargs)
#     118 return _maybe_cast_to_cftimeindex(index)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/core/indexing.py:422, in LazilyIndexedArray.__array__(self, dtype)
#     420 def __array__(self, dtype=None):
#     421     array = as_indexable(self.array)
# --> 422     return np.asarray(array[self.key], dtype=None)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/coding/variables.py:70, in _ElementwiseFunctionArray.__array__(self, dtype)
#      69 def __array__(self, dtype=None):
# ---> 70     return self.func(self.array)
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/coding/times.py:242, in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     240     dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     241 except (KeyError, OutOfBoundsDatetime, OverflowError):
# --> 242     dates = _decode_datetime_with_cftime(
#     243         flat_num_dates.astype(float), units, calendar
#     244     )
#     246     if (
#     247         dates[np.nanargmin(num_dates)].year < 1678
#     248         or dates[np.nanargmax(num_dates)].year >= 2262
#     249     ):
#     250         if _is_standard_calendar(calendar):
#
# File ~/.conda/envs/preprocess/lib/python3.8/site-packages/xarray/coding/times.py:174, in _decode_datetime_with_cftime(num_dates, units, calendar)
#     171 if cftime is None:
#     172     raise ModuleNotFoundError("No module named 'cftime'")
#     173 return np.asarray(
# --> 174     cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
#     175 )
#
# File src/cftime/_cftime.pyx:535, in cftime._cftime.num2date()
#
# File src/cftime/_cftime.pyx:380, in cftime._cftime.cast_to_int()
#
# OverflowError: time values outside range of 64 bit signed integers

# %%
def generate_freeboard_netcdf(files, tracks, dir_day, output_path):
    data_list = []
    for file in files:
        with h5py.File(file, mode='r') as f:
            for track in tracks:
                if len(f['%s/freeboard_beam_segment/' %track].keys()) < 2:
                    pass
                else:
                    # print(f['/%s/freeboard_beam_segment/latitude' %track])
                    # access the latitude
                    latvar = f['/%s/freeboard_beam_segment/latitude' %track]
                    # and rename, as a long list?
                    latitude = latvar[:]

                    # access the longitude
                    lonvar = f['/%s/freeboard_beam_segment/longitude' %track]
                    # and rename, as a long list?
                    longitude = lonvar[:]

                    # access the freeboard values 
                    dset_name = '/%s/freeboard_beam_segment/beam_fb_height' %track
                    datavar = f[dset_name]
                    # and rename as a long list
                    data = datavar[:]

                    # access the freeboard uncertainty
                    unc_var = f['/%s/freeboard_beam_segment/beam_fb_sigma' %track]
                    unc = unc_var[:]

                    # collect metadata
                    units = datavar.attrs['units']
                    long_name = datavar.attrs['long_name']
                    _FillValue = datavar.attrs['_FillValue']

                    # handle FillValue
                    data[data == _FillValue] = np.nan
                    unc[unc == _FillValue] = np.nan

                    # collect time information
                    timevar = f['/%s/freeboard_beam_segment/delta_time' %track]
                    time = timevar[:]

                    # make dataset, decode time to cftime object, and save in a list 
                    data_list.append(xr.decode_cf(xr.Dataset({"data": (["time"], data),
                                                              "error": (["time"], unc),
                                                              "lon": (["time"], longitude),
                                                              "lat": (["time"], latitude)
                                                             }, coords={"time": (['time'],
                                                                                 time,
                                                                                 {"units": "seconds since 2018-01-01"}
                                                                                )
                                                                       }
                                                            )
                                                 )
                                    )

    day_data = xr.concat(data_list, dim = 'time', compat = 'no_conflicts')
    filename = 'IS2_fb_'+dir_day+'.nc'
    day_data.to_netcdf(output_path+filename)
    print(dir_day + ' done!')

# %%
def generate_thickness_netcdf(files, dir_day, output_path):
    data_list = []
    for file in files:
        print
        ds = xr.open_dataset(file)
        
        # access the latitude
        latitude = list(ds.latitude.values)

        # access the longitude
        longitude = list(ds.longitude.values)

        # access the thickness values 
        datavar = ds.ice_thickness
        data = list(datavar.values)

        # access the thickness uncertainty
        unc = list(ds.ice_thickness_unc.values)

        # collect metadata
        units = datavar.attrs['units']
        long_name = datavar.attrs['long_name']

        # collect time information
        time = list(ds.gps_seconds.values)
                    
        # make dataset, decode time to cftime object, and save in a list 
        data_list.append(xr.decode_cf(xr.Dataset({"data": (["time"], data),
                                                  "error": (["time"], unc),
                                                  "lon": (["time"], longitude),
                                                  "lat": (["time"], latitude)
                                                 }, coords={"time": (['time'],
                                                                     time,
                                                                     {"units": "seconds since 1980-01-06"}
                                                                    )
                                                           }
                                                )
                                     )
                        )

    day_data = xr.concat(data_list, dim = 'time', compat = 'no_conflicts')
    filename = 'IS2_hi_'+dir_day+'.nc'
    day_data.to_netcdf(output_path+filename)
    print(dir_day + ' done!')

# %%
file = '/glade/scratch/mollyw/external_data/ICESat-2/thickness/2019.01.01/IS2SITDAT4_01_20190101070842_00590201_005_02_bnum1gt1l_001.nc'

# %%
ds = xr.open_dataset(file)

# %%
file = '/glade/scratch/mollyw/external_data/IS2_reduced/freeboard/IS2_fb_2019.01.01.nc'
ds2 = xr.open_dataset(file)

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 24918)
# Coordinates:
#   * time     (time) datetime64[ns] 2019-01-01T01:07:21.833454672 ... 2019-01-...
# Data variables:
#     data     (time) float32 ...
#     error    (time) float32 ...
#     lon      (time) float64 ...
#     lat      (time) float64 ...

# %%
xr.decode_cf(ds, decode_timedelta=True)
# Out:
# <xarray.Dataset>
# Dimensions:                    (index: 84382)
# Coordinates:
#   * index                      (index) int64 0 1 2 3 ... 84378 84379 84380 84381
# Data variables: (12/19)
#     gps_seconds                (index) timedelta64[ns] ...
#     height_segment_id          (index) int32 ...
#     along_track_distance       (index) float64 ...
#     latitude                   (index) float64 ...
#     longitude                  (index) float64 ...
#     ssh_flag                   (index) int8 ...
#     ...                         ...
#     ice_thickness_W99mod5dist  (index) float64 ...
#     ice_thickness_unc          (index) float64 ...
#     ice_thickness_uncsys       (index) float64 ...
#     ice_thickness_uncrandom    (index) float64 ...
#     ice_type                   (index) int64 ...
#     region_flag                (index) uint8 ...
# Attributes:
#     Description:  Along track sea ice thickness estimates from ICESat-2 and a...
#     Contact:      Alek Petty (alek.a.petty@nasa.gov)
#     Reference:    Data doi: 10.5067/JTI5YG3S6VAJ. Data described in Petty, A....
#     Conventions:  CF-1.8
#     featureType:  point
#     projection:   Data referenced to WGS84 (EPSG:4326)
